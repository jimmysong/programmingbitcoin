# %%
############## PLEASE RUN THIS CELL FIRST! ###################

# import everything and define a test runner function
from importlib import reload
from helper import run_test

import ecc
import helper

# %% [markdown]
# ### Exercise 1
#
# #### Which of these points are on the curve \\( y^2 = x^3 + 7: F_{223} \\)?
# ```
# (192,105), (17,56), (200,119), (1,193), (42,99)
# ```

# %%
# Exercise 1

from ecc import FieldElement

prime = 223
a = FieldElement(0, prime)
b = FieldElement(7, prime)

# (192,105), (17,56), (200,119), (1,193), (42,99)

# %%
from ecc import FieldElement, Point

a = FieldElement(num=0, prime=223)
b = FieldElement(num=7, prime=223)
x = FieldElement(num=192, prime=223)
y = FieldElement(num=105, prime=223)
p1 = Point(x, y, a, b)
print(p1)

# %%
import ecc

from helper import run_test

run_test(ecc.ECCTest('test_on_curve'))

# %% [markdown]
# ### Exercise 2
#
# #### For the curve  \\( y^2 = x^3 + 7: F_{223} \\) find:
# ```
# (170,142) + (60,139)
#
# (47,71) + (17,56)
#
# (143,98) + (76,66)
# ```

# %%
# Exercise 2

from ecc import FieldElement, Point

prime = 223
a = FieldElement(0, prime)
b = FieldElement(7, prime)

# (170,142) + (60,139)
# (47,71) + (17,56)
# (143,98) + (76,66)

# %%
from ecc import FieldElement, Point

prime = 223
a = FieldElement(num=0, prime=prime)
b = FieldElement(num=7, prime=prime)
x1 = FieldElement(num=192, prime=prime)
y1 = FieldElement(num=105, prime=prime)
x2 = FieldElement(num=17, prime=prime)
y2 = FieldElement(num=56, prime=prime)
p1 = Point(x1, y1, a, b)
p2 = Point(x2, y2, a, b)
print(p1+p2)

# %% [markdown]
# ### Exercise 3
#
# #### Extend [`ECCTest`](/edit/code-ch03/ecc.py) to test for the additions from the previous exercise.
#
# ```
# ecc.py:ECCTest:test_add
# ```

# %%
# Exercise 3

reload(ecc)
run_test(ecc.ECCTest('test_add'))

# %% [markdown]
# ### Exercise 4
#
# #### For the curve  \\( y^2 = x^3 + 7: F_{223} \\), find:
#
# * \\(2\cdot(192,105)\\)
# * \\(2\cdot(143,98)\\)
# * \\(2\cdot(47,71)\\)
# * \\(4\cdot(47,71)\\)
# * \\(8\cdot(47,71)\\)
# * \\(21\cdot(47,71)\\)
#
# #### Hint: add the point to itself n times

# %%
# Exercise 4

from ecc import FieldElement, Point

prime = 223
a = FieldElement(0, prime)
b = FieldElement(7, prime)

# 2*(192, 105)
# 2*(143, 98)
# 2*(47, 71)
# 4*(47, 71)
# 8*(47, 71)
# 21*(47, 71)

# %%
reload(ecc)
from ecc import FieldElement, Point

prime = 223
a = FieldElement(0, prime)
b = FieldElement(7, prime)
x = FieldElement(47, prime)
y = FieldElement(71, prime)
p = Point(x, y, a, b)
for s in range(1,21):
    result = s*p
    print('{}*(47,71)=({},{})'.format(s,result.x.num,result.y.num))

# %% [markdown]
# ### Exercise 5
#
# #### For the curve  \\( y^2 = x^3 + 7: F_{223} \\), find the order of the group generated by (15, 86)
#
# #### Hint: add the point to itself until you get the point at infinity

# %%
# Exercise 5

from ecc import FieldElement, Point

prime = 223
a = FieldElement(0, prime)
b = FieldElement(7, prime)
x = FieldElement(15, prime)
y = FieldElement(86, prime)
p = Point(x, y, a, b)
inf = Point(None, None, a, b)

# %%
from ecc import FieldElement, Point

prime = 223
a = FieldElement(0, prime)
b = FieldElement(7, prime)
x = FieldElement(15, prime)
y = FieldElement(86, prime)
p = Point(x, y, a, b)
print(7*p)

# %%
gx = 0x79be667ef9dcbbac55a06295ce870b07029bfcdb2dce28d959f2815b16f81798
gy = 0x483ada7726a3c4655da4fbfc0e1108a8fd17b448a68554199c47d08ffb10d4b8
p = 2**256 - 2**32 - 977
print(gy**2 % p == (gx**3 + 7) % p)

# %%
from ecc import FieldElement, Point

gx = 0x79be667ef9dcbbac55a06295ce870b07029bfcdb2dce28d959f2815b16f81798
gy = 0x483ada7726a3c4655da4fbfc0e1108a8fd17b448a68554199c47d08ffb10d4b8
p = 2**256 - 2**32 - 977
n = 0xfffffffffffffffffffffffffffffffebaaedce6af48a03bbfd25e8cd0364141
x = FieldElement(gx, p)
y = FieldElement(gy, p)
seven = FieldElement(7, p)
zero = FieldElement(0, p)
G = Point(x, y, zero, seven)
print(n*G)

# %%
from ecc import G, N

print(N*G)

# %%
from ecc import S256Point, G, N

z = 0xbc62d4b80d9e36da29c16c5d4d9f11731f36052c72401a76c23c0fb5a9b74423
r = 0x37206a0610995c58074999cb9767b87af4c4978db68c06e8e6e81d282047a7c6
s = 0x8ca63759c1157ebeaec0d03cecca119fc9a75bf8e6d0fa65c841c8e2738cdaec
point = S256Point(0x04519fac3d910ca7e7138f7013706f619fa8f033e6ec6e09370ea38cee6a7574, 0x82b51eab8c27c66e26c858a079bcdf4f1ada34cec420cafc7eac1a42216fb6c4)
u = z * pow(s, N-2, N) % N
v = r * pow(s, N-2, N) % N
print((u*G + v*point).x.num == r)

# %% [markdown]
# ### Exercise 6
#
# #### Verify whether these signatures are valid:
#
# ```
# P = (0x887387e452b8eacc4acfde10d9aaf7f6d9a0f975aabb10d006e4da568744d06c,
#      0x61de6d95231cd89026e286df3b6ae4a894a3378e393e93a0f45b666329a0ae34)
#
# # signature 1
# z, r, s = 0xec208baa0fc1c19f708a9ca96fdeff3ac3f230bb4a7ba4aede4942ad003c0f60,
#           0xac8d1c87e51d0d441be8b3dd5b05c8795b48875dffe00b7ffcfac23010d3a395,
#           0x68342ceff8935ededd102dd876ffd6ba72d6a427a3edb13d26eb0781cb423c4
#
# # signature 2
# z, r, s = 0x7c076ff316692a3d7eb3c3bb0f8b1488cf72e1afcd929e29307032997a838a3d,
#           0xeff69ef2b1bd93a66ed5219add4fb51e11a840f404876325a1e8ffe0529a2c,
#           0xc7207fee197d27c618aea621406f6bf5ef6fca38681d82b2f06fddbdce6feab6
# ```

# %%
# Exercise 6

from ecc import S256Point, N, G

point = S256Point(
    0x887387e452b8eacc4acfde10d9aaf7f6d9a0f975aabb10d006e4da568744d06c, 
    0x61de6d95231cd89026e286df3b6ae4a894a3378e393e93a0f45b666329a0ae34)
# signature 1
z = 0xec208baa0fc1c19f708a9ca96fdeff3ac3f230bb4a7ba4aede4942ad003c0f60
r = 0xac8d1c87e51d0d441be8b3dd5b05c8795b48875dffe00b7ffcfac23010d3a395
s = 0x68342ceff8935ededd102dd876ffd6ba72d6a427a3edb13d26eb0781cb423c4
# signature 2
z = 0x7c076ff316692a3d7eb3c3bb0f8b1488cf72e1afcd929e29307032997a838a3d
r = 0xeff69ef2b1bd93a66ed5219add4fb51e11a840f404876325a1e8ffe0529a2c
s = 0xc7207fee197d27c618aea621406f6bf5ef6fca38681d82b2f06fddbdce6feab6

# %%
from ecc import S256Point, G, N
from random import randint
from helper import double_sha256

e = int.from_bytes(double_sha256(b'my secret'), 'big')
z = int.from_bytes(double_sha256(b'my message'), 'big')
k = randint(0, N)
r = (k*G).x.num
k_inv = pow(k, N-2, N)
s = (z+r*e) * k_inv % N
point = e*G
print(point)
print(hex(z))
print(hex(r))
print(hex(s))

# %% [markdown]
# ### Exercise 7
#
# #### Sign the following message with the secret
#
# ```
# e = 12345
# z = int.from_bytes(double_sha256('Programming Bitcoin!'), 'big')
# ```

# %%
# Exercise 7

from ecc import S256Point, G, N
from random import randint
from helper import double_sha256

e = 12345
z = int.from_bytes(double_sha256(b'Programming Bitcoin!'), 'big')

# print the point, z, r and s
